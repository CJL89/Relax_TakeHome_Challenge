# %%
import pandas as pd
import numpy as np
import json
from datetime import datetime
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 7.5)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
df_engagement = pd.read_csv('takehome_user_engagement.csv')
df.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
df_users = pd.read_csv('takehome_users.csv', encoding='latin-1')
df_users.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id
# 0             10803.0
# 1               316.0
# 2              1525.0
# 3              5151.0
# 4              5240.0

# %%
df_engagement['time_stamp'] = pd.to_datetime(df_engagement['time_stamp'])
df_engagement.drop(['visited'], axis=1, inplace=True)

# %%
grouped_users = pd.DataFrame(df_engagement.groupby('user_id')['time_stamp'].apply(list))
grouped_index = list(grouped_users.index)
grouped_timestamps = list(grouped_users['time_stamp'])

# %%
def is_adopted(timestamps):
    '''Takes in a list of datetimes and returns 1 if the user is adopted, 
    and 0 if the user is not adopted'''
    
    timestamps = pd.DataFrame(timestamps)
    timestamps[0] = pd.to_datetime(timestamps[0])
    timecounts = timestamps.set_index(0).sort_index().resample('1W').size()
    
    for i in timecounts:
        if i >= 3:
            return 1
    return 0

# %%
# weekly = df_engagement.set_index('time_stamp').sort_index().resample('1W').size()
adapted = list(map(is_adopted, grouped_timestamps))

# %%
df_adopted = pd.DataFrame({'object_id':grouped_index, 'adopted':adapted})
df_adopted.head()
# Out:
#    object_id  adopted
# 0          1        0
# 1          2        1
# 2          3        0
# 3          4        0
# 4          5        0

# %%
df_clean = pd.merge(df_users, df_adopted, on='object_id', how='outer')
df_clean.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id  adopted
# 0             10803.0      0.0
# 1               316.0      1.0
# 2              1525.0      0.0
# 3              5151.0      0.0
# 4              5240.0      0.0

# %%
df_clean.drop(['email'], axis=1, inplace=True)
df_clean.head()
# Out:
#    object_id        creation_time               name creation_source  \
# 0          1  2014-04-22 03:53:30     Clausen August    GUEST_INVITE
# 1          2  2013-11-15 03:45:04      Poole Matthew      ORG_INVITE
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell      ORG_INVITE
# 3          4  2013-05-21 08:09:28    Clausen Nicklas    GUEST_INVITE
# 4          5  2013-01-17 10:14:20          Raw Grace    GUEST_INVITE
#
#    last_session_creation_time  opted_in_to_mailing_list  \
# 0                1.398139e+09                         1
# 1                1.396238e+09                         0
# 2                1.363735e+09                         0
# 3                1.369210e+09                         0
# 4                1.358850e+09                         0
#
#    enabled_for_marketing_drip  org_id  invited_by_user_id  adopted
# 0                           0      11             10803.0      0.0
# 1                           0       1               316.0      1.0
# 2                           0      94              1525.0      0.0
# 3                           0       1              5151.0      0.0
# 4                           0     193              5240.0      0.0

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
# object_id                     12000 non-null int64
# creation_time                 12000 non-null object
# name                          12000 non-null object
# creation_source               12000 non-null object
# last_session_creation_time    8823 non-null float64
# opted_in_to_mailing_list      12000 non-null int64
# enabled_for_marketing_drip    12000 non-null int64
# org_id                        12000 non-null int64
# invited_by_user_id            6417 non-null float64
# adopted                       8823 non-null float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 1.0+ MB

# %%
df_clean['last_session_creation_time'] = df_clean['last_session_creation_time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))
df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/indexes/datetimelike.py in map(self, mapper, na_action)
#     241         try:
# --> 242             result = mapper(self)
#     243
#
# <ipython-input-95-4b64d28055d1> in <lambda>(x)
# ----> 1 df_clean['last_session_creation_time'] = df_clean['last_session_creation_time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))
#       2 df_clean.head()
#
# TypeError: an integer is required (got type DatetimeIndex)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-4b64d28055d1> in <module>
# ----> 1 df_clean['last_session_creation_time'] = df_clean['last_session_creation_time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))
#       2 df_clean.head()
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3819         dtype: object
#    3820         """
# -> 3821         new_values = super()._map_values(arg, na_action=na_action)
#    3822         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3823
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/base.py in <lambda>(values, f)
#    1285             if na_action is not None:
#    1286                 raise NotImplementedError
# -> 1287             map_f = lambda values, f: values.map(f)
#    1288         else:
#    1289             values = self.astype(object)
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py in map(self, mapper)
#     720         from pandas import Index
#     721
# --> 722         return Index(self).map(mapper).array
#     723
#     724     # ------------------------------------------------------------------
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/indexes/datetimelike.py in map(self, mapper, na_action)
#     250             return result
#     251         except Exception:
# --> 252             return self.astype(object).map(mapper)
#     253
#     254     def sort_values(self, return_indexer=False, ascending=True):
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/indexes/base.py in map(self, mapper, na_action)
#    4872         from .multi import MultiIndex
#    4873
# -> 4874         new_values = super()._map_values(mapper, na_action=na_action)
#    4875
#    4876         attributes = self._get_attributes_dict()
#
# //anaconda3/envs/Springboard/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-95-4b64d28055d1> in <lambda>(x)
# ----> 1 df_clean['last_session_creation_time'] = df_clean['last_session_creation_time'].map(lambda x: datetime.utcfromtimestamp(x).strftime('%Y-%m-%d %H:%M:%S'))
#       2 df_clean.head()
#
# TypeError: an integer is required (got type Timestamp)
